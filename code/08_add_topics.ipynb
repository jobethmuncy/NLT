# %% [markdown]
# ## Imports

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import gensim
import gensim.corpora as corpora
from gensim.utils import simple_preprocess
from gensim.models import CoherenceModel, HdpModel
from gensim.models.doc2vec import Doc2Vec, TaggedDocument
from gensim.test.utils import common_texts
from gensim.parsing.preprocessing import strip_tags, strip_punctuation, strip_multiple_whitespaces, remove_stopwords, preprocess_string

from tqdm import tqdm_notebook as tqdm

# %% [markdown]
# ## Read in data

# %%
# Read in articles
articles = pd.read_csv('NLT_data/merged_data.csv')

# %%
articles.shape
# Out:
# (37562, 10)

# %%
articles.head(2)
# Out:
#                                    paper_id source  \
# 0  b2897e1277f56641193a6db73825f707eed3e4c9    PMC
# 1  e3d0d482ebd9a8ba81c254cc433f314142e72174    PMC
#
#                                                title  \
# 0  Sequence requirements for RNA strand transfer ...
# 1  Crystal structure of murine sCEACAM1a[1,4]: a ...
#
#                                             abstract publish_time  \
# 0  Nidovirus subgenomic mRNAs contain a leader se...   2001-12-17
# 1  CEACAM1 is a member of the carcinoembryonic an...   2002-05-01
#
#                                              authors           journal  \
# 0  Pasternak, Alexander O.; van den Born, Erwin; ...  The EMBO Journal
# 1  Tan, Kemin; Zelus, Bruce D.; Meijers, Rob; Liu...  The EMBO Journal
#
#                                                  url discussion  \
# 0  http://europepmc.org/articles/pmc125340?pdf=re...        NaN
# 1  http://europepmc.org/articles/pmc125375?pdf=re...        NaN
#
#                                            text_body
# 0  The genetic information of RNA viruses is orga...
# 1  Carcinoembryonic antigen (CEA; CD66e) was init...

# %%
# Read in topics 
topics = pd.read_csv('df_dominant_topic.csv')

# %%
topics.shape
# Out:
# (37562, 5)

# %%
topics.head()
# Out:
#    Document_No  Dominant_Topic  Topic_Perc_Contrib  \
# 0            0            18.0              0.5541
# 1            1            18.0              0.2898
# 2            2            18.0              0.3064
# 3            3            18.0              0.5376
# 4            4            18.0              0.4824
#
#                                             Keywords  \
# 0  protein, proteins, rna, binding, membrane, str...
# 1  protein, proteins, rna, binding, membrane, str...
# 2  protein, proteins, rna, binding, membrane, str...
# 3  protein, proteins, rna, binding, membrane, str...
# 4  protein, proteins, rna, binding, membrane, str...
#
#                                                 Text
# 0  ['nidovirus', 'subgenomic', 'mrnas', 'contain'...
# 1  ['ceacam1', 'member', 'carcinoembryonic', 'ant...
# 2  ['hepatitis', 'c', 'virus', 'hcv', 'important'...
# 3  ['key', 'enzyme', 'coronavirus', 'polyprotein'...
# 4  ['arteri', 'corona', 'toro', 'roniviruses', 'e...

# %% [markdown]
# ## Concatenate topics to original dataframe

# %%
articles_with_top = pd.concat([topics, articles], axis=1)

# %%
articles_with_top.head()
# Out:
#    Document_No  Dominant_Topic  Topic_Perc_Contrib  \
# 0            0            18.0              0.5541
# 1            1            18.0              0.2898
# 2            2            18.0              0.3064
# 3            3            18.0              0.5376
# 4            4            18.0              0.4824
#
#                                             Keywords  \
# 0  protein, proteins, rna, binding, membrane, str...
# 1  protein, proteins, rna, binding, membrane, str...
# 2  protein, proteins, rna, binding, membrane, str...
# 3  protein, proteins, rna, binding, membrane, str...
# 4  protein, proteins, rna, binding, membrane, str...
#
#                                                 Text  \
# 0  ['nidovirus', 'subgenomic', 'mrnas', 'contain'...
# 1  ['ceacam1', 'member', 'carcinoembryonic', 'ant...
# 2  ['hepatitis', 'c', 'virus', 'hcv', 'important'...
# 3  ['key', 'enzyme', 'coronavirus', 'polyprotein'...
# 4  ['arteri', 'corona', 'toro', 'roniviruses', 'e...
#
#                                    paper_id source  \
# 0  b2897e1277f56641193a6db73825f707eed3e4c9    PMC
# 1  e3d0d482ebd9a8ba81c254cc433f314142e72174    PMC
# 2  00b1d99e70f779eb4ede50059db469c65e8c1469    PMC
# 3  cf584e00f637cbd8f1bb35f3f09f5ed07b71aeb0    PMC
# 4  dde02f11923815e6a16a31dd6298c46b109c5dfa    PMC
#
#                                                title  \
# 0  Sequence requirements for RNA strand transfer ...
# 1  Crystal structure of murine sCEACAM1a[1,4]: a ...
# 2  Synthesis of a novel hepatitis C virus protein...
# 3  Structure of coronavirus main proteinase revea...
# 4  Discontinuous and non-discontinuous subgenomic...
#
#                                             abstract publish_time  \
# 0  Nidovirus subgenomic mRNAs contain a leader se...   2001-12-17
# 1  CEACAM1 is a member of the carcinoembryonic an...   2002-05-01
# 2  Hepatitis C virus (HCV) is an important human ...   2001-07-16
# 3  The key enzyme in coronavirus polyprotein proc...   2002-07-01
# 4  Arteri-, corona-, toro- and roniviruses are ev...   2002-12-01
#
#                                              authors           journal  \
# 0  Pasternak, Alexander O.; van den Born, Erwin; ...  The EMBO Journal
# 1  Tan, Kemin; Zelus, Bruce D.; Meijers, Rob; Liu...  The EMBO Journal
# 2  Xu, Zhenming; Choi, Jinah; Yen, T.S.Benedict; ...            EMBO J
# 3  Anand, Kanchan; Palm, Gottfried J.; Mesters, J...  The EMBO Journal
# 4  van Vliet, A.L.W.; Smits, S.L.; Rottier, P.J.M...  The EMBO Journal
#
#                                                  url  \
# 0  http://europepmc.org/articles/pmc125340?pdf=re...
# 1  http://europepmc.org/articles/pmc125375?pdf=re...
# 2  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC1...
# 3  http://europepmc.org/articles/pmc126080?pdf=re...
# 4  http://europepmc.org/articles/pmc136939?pdf=re...
#
#                                           discussion  \
# 0                                                NaN
# 1                                                NaN
# 2  Previous studies have demonstrated that the lo...
# 3                                                NaN
# 4                                                NaN
#
#                                            text_body
# 0  The genetic information of RNA viruses is orga...
# 1  Carcinoembryonic antigen (CEA; CD66e) was init...
# 2  Hepatitis C virus (HCV) is a positive-stranded...
# 3  Transmissible gastroenteritis virus (TGEV) bel...
# 4  Positive (+)-strand RNA viruses have developed...

# %% [markdown]
# ## Drop duplicate rows

# %%
articles_with_top_dropped = articles_with_top.drop_duplicates(subset='title')

# %%
articles_with_top_dropped.shape # 354 rows removed
# Out:
# (37208, 15)

# %%
# Save out as csv
articles_with_top_dropped.to_csv('articles_with_topics.csv', index=False)

# %% [markdown]
# ## Train on Doc2Vec model
# Taken from Clay's code in `gensim_doc2vec_recommender.ipynb` notebook.

# %%
articles_with_top_dropped.isnull().sum()
# Out:
# Document_No               0
# Dominant_Topic            0
# Topic_Perc_Contrib        0
# Keywords                  0
# Text                      0
# paper_id                  0
# source                    0
# title                     0
# abstract               4923
# publish_time              0
# authors                 397
# journal                3344
# url                     103
# discussion            21649
# text_body                 0
# dtype: int64

# %% [markdown]
# ### Cleaning

# %%
df = articles_with_top_dropped.copy()

# %%
# filling some missing abstract values with the discussion section
df['abstract'] = df['abstract'].fillna(value = df['discussion'])
# Filling the rest with the title value
df['abstract'] = df['abstract'].fillna(value = df['title'])

# %%
# funtion for cleaning text
def preprocess(text):
    ls = []
    for i in tqdm(text):
        custom_filters = [strip_tags, strip_punctuation, strip_multiple_whitespaces, 
                          remove_stopwords]
        ls.append(preprocess_string(i.lower(), custom_filters))
    return ls

# %%
raw_data = df['abstract']

# %%
data = preprocess(raw_data)
# Out:
# /Users/cynthia/opt/anaconda3/envs/dsi/lib/python3.7/site-packages/ipykernel_launcher.py:4: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   after removing the cwd from sys.path.
# HBox(children=(FloatProgress(value=0.0, max=37208.0), HTML(value='')))

# %% [markdown]
# ### Model training

# %%
def create_tagged_document(list_of_list_of_words):
    for i, list_of_words in enumerate(list_of_list_of_words):
        yield TaggedDocument(list_of_words, [i])

# %%
data_tagged = list(create_tagged_document(data))

# %%
model = Doc2Vec(vector_size = 200, min_count = 3, epochs = 20)

# %%
model.build_vocab(data_tagged)

# %%
# %%time
model.train(data_tagged, total_examples = model.corpus_count, epochs = model.epochs)
# Out:
# CPU times: user 4min 44s, sys: 9.06 s, total: 4min 53s
# Wall time: 2min 2s

# %%
model.save('doc2vec_updated.model')

# %%
# Grab most similar articles of the input word and its most similar words 
def most_sim_docs(word, n_articles, topn=3):
    dfs = []
    sims = []
    
    # Input word with topn of its most similar keywords
    keywords = [word] + [w[0] for w in model.wv.most_similar_cosmul(word, topn=topn)]
    
    # Loop through each keyword
    for term in keywords:
        new_vec = model.infer_vector([term]) # random, different everytime 
        tag_list = model.docvecs.most_similar([new_vec])[0:n_articles]
        
        
        tags = [] 
        for num in tag_list:
            tags.append(num[0])
            sims.append(num[1])
        
        for t in tags:
            dfs.append(df.iloc[t, :])
        
    new_df = pd.DataFrame(dfs)
    new_df['similarity_percentage'] = sims
    
    return new_df

# %%
protein = most_sim_docs('protein', 2)

# %%
protein.iloc[1]['Keywords']
# Out:
# 'protein, proteins, rna, binding, membrane, structure, sequence, cell, domain, structural'

# %%
protein
# Out:
#        Document_No  Dominant_Topic  Topic_Perc_Contrib  \
# 14831        14831            18.0              0.4355
# 12585        12585            18.0              0.6381
# 14831        14831            18.0              0.4355
# 18304        18304            18.0              0.6319
# 14831        14831            18.0              0.4355
# 21863        21863            13.0              0.5115
# 9758          9758             3.0              0.1879
# 14831        14831            18.0              0.4355
#
#                                                 Keywords  \
# 14831  protein, proteins, rna, binding, membrane, str...
# 12585  protein, proteins, rna, binding, membrane, str...
# 14831  protein, proteins, rna, binding, membrane, str...
# 18304  protein, proteins, rna, binding, membrane, str...
# 14831  protein, proteins, rna, binding, membrane, str...
# 21863  care, health, patients, medical, patient, risk...
# 9758   al, cells, cell, acid, 2, found, 1, activity, ...
# 14831  protein, proteins, rna, binding, membrane, str...
#
#                                                     Text  \
# 14831  ['inference', 'accomplished', 'assigning', 'pe...
# 12585  ['number', 'approaches', 'taken', 'elucidate',...
# 14831  ['inference', 'accomplished', 'assigning', 'pe...
# 18304  ['palmitoylation', "tn)'nstoylation", '1ypiati...
# 14831  ['inference', 'accomplished', 'assigning', 'pe...
# 21863  ['april', '15', '2020', '1', '918', '138', 'co...
# 9758   ['avian', 'infectious', 'bronchitis', 'virus',...
# 14831  ['inference', 'accomplished', 'assigning', 'pe...
#
#                                        paper_id    source  \
# 14831  6747c4bf9d71daeab63b36eada34498f0346bf4a       PMC
# 12585  fc4839e258edd3040fe5bf354a6bf1b0ebcff19b       PMC
# 14831  6747c4bf9d71daeab63b36eada34498f0346bf4a       PMC
# 18304  0f1791125afe17384fcaef1cd0aa40f82b5269ba  Elsevier
# 14831  6747c4bf9d71daeab63b36eada34498f0346bf4a       PMC
# 21863  fcb6109e808c165aef9bdcacb8e45184c75d21e0  Elsevier
# 9758   12ce8410d1ca0fa6f438c4f22bd92af6f8b78f04       PMC
# 14831  6747c4bf9d71daeab63b36eada34498f0346bf4a       PMC
#
#                                                    title  \
# 14831   Protein Analysis by Shotgun/Bottom-up Proteomics
# 12585  Genetic and Molecular Biological Analysis of P...
# 14831   Protein Analysis by Shotgun/Bottom-up Proteomics
# 18304                        Fatty acylation of proteins
# 14831   Protein Analysis by Shotgun/Bottom-up Proteomics
# 21863  Focusing on health-care providers' experiences...
# 9758   The polypeptide composition of avian infectiou...
# 14831   Protein Analysis by Shotgun/Bottom-up Proteomics
#
#                                                 abstract publish_time  \
# 14831   Protein Analysis by Shotgun/Bottom-up Proteomics   2013-02-26
# 12585  Genetic and Molecular Biological Analysis of P...   2006-01-01
# 14831   Protein Analysis by Shotgun/Bottom-up Proteomics   2013-02-26
# 18304                        Fatty acylation of proteins   1989-12-06
# 14831   Protein Analysis by Shotgun/Bottom-up Proteomics   2013-02-26
# 21863  Focusing on health-care providers' experiences...   2020-04-29
# 9758   Avian infectious bronchitis virus grownin ovo ...   1975-01-01
# 14831   Protein Analysis by Shotgun/Bottom-up Proteomics   2013-02-26
#
#                                                  authors  \
# 14831  Zhang, Yaoyang; Fonslow, Bryan R.; Shan, Bing;...
# 12585  Masters, Paul S.; Kuo, Lili; Ye, Rong; Hurst, ...
# 14831  Zhang, Yaoyang; Fonslow, Bryan R.; Shan, Bing;...
# 18304                              Schmidt, Michael F.G.
# 14831  Zhang, Yaoyang; Fonslow, Bryan R.; Shan, Bing;...
# 21863                          Xiong, Yang; Peng, Lingli
# 9758                                      Bingham, R. W.
# 14831  Zhang, Yaoyang; Fonslow, Bryan R.; Shan, Bing;...
#
#                                                  journal  \
# 14831                                   Chemical Reviews
# 12585                                    The Nidoviruses
# 14831                                   Chemical Reviews
# 18304  Biochimica et Biophysica Acta (BBA) - Reviews ...
# 14831                                   Chemical Reviews
# 21863                           The Lancet Global Health
# 9758                                          Arch Virol
# 14831                                   Chemical Reviews
#
#                                                      url  discussion  \
# 14831  http://europepmc.org/articles/pmc3751594?pdf=r...         NaN
# 12585  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7...         NaN
# 14831  http://europepmc.org/articles/pmc3751594?pdf=r...         NaN
# 18304       https://doi.org/10.1016/0304-4157(89)90013-0         NaN
# 14831  http://europepmc.org/articles/pmc3751594?pdf=r...         NaN
# 21863      https://doi.org/10.1016/s2214-109x(20)30214-x         NaN
# 9758   https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7...         NaN
# 14831  http://europepmc.org/articles/pmc3751594?pdf=r...         NaN
#
#                                                text_body  \
# 14831  inference is accomplished by assigning peptide...
# 12585  A number of approaches have been taken to eluc...
# 14831  inference is accomplished by assigning peptide...
# 18304  palmitoylation, tn)'nstoylation and $1ypiation...
# 14831  inference is accomplished by assigning peptide...
# 21863  As of April 15, 2020, there have been 1 918 13...
# 9758   The eoronaviruses have been classified as a se...
# 14831  inference is accomplished by assigning peptide...
#
#        similarity_percentage
# 14831               0.860158
# 12585               0.803823
# 14831               0.810082
# 18304               0.808822
# 14831               0.719687
# 21863               0.678215
# 9758                0.722517
# 14831               0.706015

# %% [markdown]
# ## Assigning topic number to name

# %%
topic_list = [f"Topic {i}" for i in range(1, 26)]
topic_dict = {topic: float(i) for i, topic in enumerate(topic_list)}
topic_dict
# Out:
# {'Topic 1': 0.0,
#  'Topic 2': 1.0,
#  'Topic 3': 2.0,
#  'Topic 4': 3.0,
#  'Topic 5': 4.0,
#  'Topic 6': 5.0,
#  'Topic 7': 6.0,
#  'Topic 8': 7.0,
#  'Topic 9': 8.0,
#  'Topic 10': 9.0,
#  'Topic 11': 10.0,
#  'Topic 12': 11.0,
#  'Topic 13': 12.0,
#  'Topic 14': 13.0,
#  'Topic 15': 14.0,
#  'Topic 16': 15.0,
#  'Topic 17': 16.0,
#  'Topic 18': 17.0,
#  'Topic 19': 18.0,
#  'Topic 20': 19.0,
#  'Topic 21': 20.0,
#  'Topic 22': 21.0,
#  'Topic 23': 22.0,
#  'Topic 24': 23.0,
#  'Topic 25': 24.0}

# %%
# Search articles by topic name
articles_with_top_dropped.loc[df['Dominant_Topic'] == dic['Topic 4']]
# Out:
#        Document_No  Dominant_Topic  Topic_Perc_Contrib  \
# 399            399             3.0              0.3540
# 616            616             3.0              0.1495
# 660            660             3.0              0.3158
# 870            870             3.0              0.2695
# 1286          1286             3.0              0.2976
# ...            ...             ...                 ...
# 37454        37454             3.0              0.2834
# 37462        37462             3.0              0.1380
# 37526        37526             3.0              0.2536
# 37546        37546             3.0              0.3374
# 37554        37554             3.0              0.2290
#
#                                                 Keywords  \
# 399    al, cells, cell, acid, 2, found, 1, activity, ...
# 616    al, cells, cell, acid, 2, found, 1, activity, ...
# 660    al, cells, cell, acid, 2, found, 1, activity, ...
# 870    al, cells, cell, acid, 2, found, 1, activity, ...
# 1286   al, cells, cell, acid, 2, found, 1, activity, ...
# ...                                                  ...
# 37454  al, cells, cell, acid, 2, found, 1, activity, ...
# 37462  al, cells, cell, acid, 2, found, 1, activity, ...
# 37526  al, cells, cell, acid, 2, found, 1, activity, ...
# 37546  al, cells, cell, acid, 2, found, 1, activity, ...
# 37554  al, cells, cell, acid, 2, found, 1, activity, ...
#
#                                                     Text  \
# 399    ['background', 'describe', 'new', 'technical',...
# 616    ['background', 'phaseolus', 'vulgaris', 'commo...
# 660    ['background', 'aims', 'tuberization', 'mechan...
# 870    ['background', 'hepatitis', 'c', 'virus', 'hcv...
# 1286   ['scutellaria', 'species', 'lamiaceae', 'used'...
# ...                                                  ...
# 37454  ['abstract', 'japanese', 'encephalitis', 'viru...
# 37462  ['abstract', 'hotels', 'designed', 'provide', ...
# 37526  ['abstract', 'hybridisation-based', 'genosenso...
# 37546  ['blindness', 'one', 'major', 'health', 'probl...
# 37554  ['abstract', 'analysis', 'protein', 'compositi...
#
#                                        paper_id    source  \
# 399    0e7e8aa9e5d952e8486bc9599764a9fcddd7f579       PMC
# 616    8013bbf01944aa3f25d0faf16386ea51c7586066       PMC
# 660    9966ccef050ac0dc4d794363dbd1f865442ef0aa       PMC
# 870    b9b85a4893f9ed75881adcedbf142098bd7edc93       PMC
# 1286   abf6f66d8e18b652d10944bb21e19debca5dc5e8       PMC
# ...                                         ...       ...
# 37454  6a5ff06ef79286c7bf9d24bd03caffd7ca534393  Elsevier
# 37462  59eadcaf2ef4085813b911b168d11035a9d2f026  Elsevier
# 37526  372516ceb5b840cbc46c7aa04ca7907d7596bce1  Elsevier
# 37546  ec280cc8cac358abfae9c00b8b72eecd55c2fed0  Elsevier
# 37554  6f84454ada9a8c94757cc98d9c8aa1fd609ad7f9  Elsevier
#
#                                                    title  \
# 399    Improved production of human type II procollag...
# 616    Generation of Phaseolus vulgaris ESTs and inve...
# 660    IbMADS1 (Ipomoea batatas MADS-box 1 gene) is I...
# 870    Thermal stability and inactivation of hepatiti...
# 1286   Analyzing Cytotoxic and Apoptogenic Properties...
# ...                                                  ...
# 37454  Maturation of Japanese encephalitis virus glyc...
# 37462  Indoor air quality audit implementation in a h...
# 37526  Genosensor on gold films with enzymatic electr...
# 37546  Retinal degenerations of hereditary, viral and...
# 37554   Protein composition of tomato spotted wilt virus
#
#                                                 abstract publish_time  \
# 399    BACKGROUND: Here we describe a new technical s...   2008-03-27
# 616    BACKGROUND: Phaseolus vulgaris (common bean) i...   2009-04-27
# 660    BACKGROUND AND AIMS: The tuberization mechanis...   2008-05-07
# 870    BACKGROUND: Hepatitis C virus (HCV) is a blood...   2010-02-18
# 1286   The Scutellaria species (Lamiaceae) is used as...   2011-03-09
# ...                                                  ...          ...
# 37454  Abstract The Japanese encephalitis virus (JE) ...   1989-04-30
# 37462  Abstract Hotels are designed to provide high l...   2011-08-31
# 37526  Abstract A hybridisation-based genosensor was ...   2005-05-15
# 37546  Retinal degenerations of hereditary, viral and...   1994-12-31
# 37554  Abstract Analysis of the protein composition o...   1973-11-30
#
#                                                  authors  \
# 399    Ruottinen, Maria; Bollok, Monika; Kögler, Mart...
# 616    Thibivilliers, Sandra; Joshi, Trupti; Campbell...
# 660    Ku, Amy Tsu; Huang, Yi-Shiuan; Wang, Yu-Shu; M...
# 870    Song, Hongshuo; Li, Jin; Shi, Shuang; Yan, Lin...
# 1286   Tayarani-Najaran, Zahra; Emami, Seyed Ahmad; A...
# ...                                                  ...
# 37454                                    Mason, Peter W.
# 37462  Asadi, Ehsan; Costa, J.J.; Gameiro da Silva, M...
# 37526  Abad-Valle, Patricia; Fernández-Abedul, M. Ter...
# 37546                                  Chader, Gerald J.
# 37554      Mohamed, N.A.; Randles, J.W.; Francki, R.I.B.
#
#                                     journal  \
# 399                          BMC Biotechnol
# 616                          BMC Plant Biol
# 660                        Annals of Botany
# 870                                 Virol J
# 1286     Evid Based Complement Alternat Med
# ...                                     ...
# 37454                              Virology
# 37462              Building and Environment
# 37526         Biosensors and Bioelectronics
# 37546  Progress in Retinal and Eye Research
# 37554                              Virology
#
#                                                      url  \
# 399    https://www.ncbi.nlm.nih.gov/pmc/articles/PMC2...
# 616    https://www.ncbi.nlm.nih.gov/pmc/articles/PMC2...
# 660    https://academic.oup.com/aob/article-pdf/102/1...
# 870    https://www.ncbi.nlm.nih.gov/pmc/articles/PMC2...
# 1286   https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3...
# ...                                                  ...
# 37454       https://doi.org/10.1016/0042-6822(89)90161-x
# 37462     https://doi.org/10.1016/j.buildenv.2011.01.027
# 37526         https://doi.org/10.1016/j.bios.2004.10.019
# 37546       https://doi.org/10.1016/1350-9462(94)90005-1
# 37554       https://doi.org/10.1016/0042-6822(73)90283-3
#
#                                               discussion  \
# 399    Experiments at the scale of shake flasks are g...
# 616                                                  NaN
# 660    A global gene analysis by cDNA-AFLP (Fig. 1) w...
# 870    In this study, a detailed analysis was conduct...
# 1286   Natural products have long been used to preven...
# ...                                                  ...
# 37454                                                NaN
# 37462  In the course of this audit, some problems or ...
# 37526                                                NaN
# 37546                                                NaN
# 37554                                                NaN
#
#                                                text_body
# 399    The methylotrophic yeast Pichia pastoris is a ...
# 616    Common bean, Phaseolus vulgaris, represents a ...
# 660    Tubers are among the principal food crops in t...
# 870    Hepatitis C virus (HCV) is a small enveloped, ...
# 1286   Plant materials have served as medicines acros...
# ...                                                  ...
# 37454  Japanese encephalitis virus (JE) is one of the...
# 37462  Hotels are designed to provide high overall co...
# 37526  Biosensors have become a very important area o...
# 37546  Blindness is one of the major health problems ...
# 37554  Tomato spot.ted wilt virus (TSWV) has been par...
#
# [643 rows x 15 columns]
